# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../data/register.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0        統一編號                     營業地址    營業人名稱       資本額  \
# 0           0  38965019.0       南投縣中寮鄉中寮村永平路３７１號一樓     原味商行  100000.0
# 1           1  61194605.0          南投縣中寮鄉中寮村鄉林巷４３號     和興商店    1000.0
# 2           2  82554400.0        南投縣中寮鄉中寮村鄉林巷５１之１號  啓輝環管企業社   50000.0
# 3           3  47588972.0  南投縣中寮鄉中寮村００７鄰鄉林巷４３―１號一樓    龍昇工程行  248000.0
# 4           4  21822468.0      南投縣中寮鄉中寮村１鄰鄉林巷１－１０號  廣福鐵材加工行  240000.0
# 5           5  99925659.0    南投縣中寮鄉中寮村１２鄰永平路３６９－６號   百味香小吃部    3000.0
# 6           6  19246243.0        南投縣中寮鄉中寮村７鄰鄉林巷４２號    建隆工程行  250000.0
# 7           7  87004192.0        南投縣中寮鄉內城村月桃巷８１之５號  月桃香休閒農場   30000.0
# 8           8  99944261.0          南投縣中寮鄉內城村月桃巷８１號    月桃香農場    3000.0
# 9           9  25277284.0          南投縣中寮鄉內城村月桃巷９５號    湧進工程行  100000.0
#
#         設立日期 組織別名稱 使用統一發票      行業代號         名稱
# 0  1040413.0    獨資      N  472927.0     豆類製品零售
# 1   400711.0    獨資      N  472913.0       菸酒零售
# 2  1081106.0    獨資      N  812100.0  建築物一般清潔服務
# 3  1051101.0    獨資      Y  434013.0   房屋設備安裝工程
# 4   940419.0    獨資      Y  431017.0      紮鋼筋工程
# 5   931001.0    獨資      N  561113.0     麵店、小吃店
# 6   890324.0    獨資      Y  771100.0  營造用機械設備租賃
# 7  1090401.0    獨資      N  559099.0    未分類其他住宿
# 8   931108.0    獨資      N  561115.0      餐館、餐廳
# 9   980406.0    獨資      Y  439012.0       模板工程

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1568814 entries, 0 to 1568813
# Data columns (total 10 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Unnamed: 0  1568814 non-null  int64
#  1   統一編號        1568814 non-null  float64
#  2   營業地址        1568814 non-null  object
#  3   營業人名稱       1568814 non-null  object
#  4   資本額         1568814 non-null  float64
#  5   設立日期        1568814 non-null  float64
#  6   組織別名稱       1568814 non-null  object
#  7   使用統一發票      1568814 non-null  object
#  8   行業代號        1568814 non-null  float64
#  9   名稱          1568814 non-null  object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 119.7+ MB

# %%
# 取出飲料業
drink=df[df['行業代號'].astype(str).str.contains('563.*')]

# %%
# 捨棄不要的欄位
drink.drop('Unnamed: 0',axis=1,inplace=True)
# Out:
# C:\Users\ininl\AppData\Local\Temp\ipykernel_7028\2179440318.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drink.drop('Unnamed: 0',axis=1,inplace=True)

# %%
drink.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29728 entries, 164 to 1568791
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統一編號    29728 non-null  float64
#  1   營業地址    29728 non-null  object
#  2   營業人名稱   29728 non-null  object
#  3   資本額     29728 non-null  float64
#  4   設立日期    29728 non-null  float64
#  5   組織別名稱   29728 non-null  object
#  6   使用統一發票  29728 non-null  object
#  7   行業代號    29728 non-null  float64
#  8   名稱      29728 non-null  object
# dtypes: float64(4), object(5)
# memory usage: 2.3+ MB

# %%
# 存檔
drink.to_csv('../data/regi_drinks.csv',encoding='utf_8_sig',index=False)

# %%
# 歇業
dfc=pd.read_csv('../data/close.csv')

# %%
# 取出飲料業
drinkc=dfc[dfc['行業代號'].astype(str).str.contains('563.*')]

# %%
# 捨棄不要的欄位
drinkc.drop('Unnamed: 0',axis=1,inplace=True)
# Out:
# C:\Users\ininl\AppData\Local\Temp\ipykernel_10824\924478855.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drinkc.drop('Unnamed: 0',axis=1,inplace=True)

# %%
drinkc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49582 entries, 186 to 1678648
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   統一編號    49582 non-null  float64
#  1   營業地址    49582 non-null  object
#  2   營業人名稱   49582 non-null  object
#  3   資本額     49582 non-null  float64
#  4   設立日期    49581 non-null  float64
#  5   使用統一發票  49582 non-null  object
#  6   行業代號    49582 non-null  float64
#  7   名稱      49485 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 3.4+ MB

# %%
# 存檔
drinkc.to_csv('../data/close_drinks.csv',encoding='utf_8_sig',index=False)

# %%
# 變更
dfch=pd.read_csv('../data/change.csv')
dfch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106017 entries, 0 to 106016
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  106017 non-null  int64
#  1   統一編號        106017 non-null  float64
#  2   營業地址        106017 non-null  object
#  3   營業人名稱       106017 non-null  object
#  4   資本額         106017 non-null  float64
#  5   設立日期        106017 non-null  float64
#  6   停業日期        105991 non-null  float64
#  7   使用統一發票      106017 non-null  object
#  8   行業代號        106017 non-null  float64
#  9   名稱          106017 non-null  object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 8.1+ MB

# %%
# 取出飲料業
drinkch=dfch[dfch['行業代號'].astype(str).str.contains('^563.*')]

# %%
# 捨棄不要的欄位
drinkch.drop('Unnamed: 0',axis=1,inplace=True)
# Out:
# C:\Users\ininl\AppData\Local\Temp\ipykernel_6768\3420599156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drinkch.drop('Unnamed: 0',axis=1,inplace=True)

# %%
drinkch.head(20)
# Out:
#       Unnamed: 0        統一編號                          營業地址     營業人名稱  \
# 79            79  26893716.0              南投縣南投市三和里公園南街４３號   大南投美食冰城
# 201          201  72426271.0            南投縣南投市崇文里復興路１５５號一樓      正宸商行
# 213          213  82523913.0           南投縣南投市平和里００６鄰南陽路８９號  水果籃子果汁小舖
# 319          319  88454603.0           南投縣南投市漳和里文林路８９巷１號１樓      䅃羽茶堂
# 329          329  81503951.0       南投縣南投市漳和里１１鄰彰南路２段２７１號１樓        茶饌
# 353          353  87293518.0            南投縣南投市營北里營北路５０２號１樓      瑞格商行
# 490          490  47533724.0             南投縣國姓鄉北港村北圳巷２８―１號      魔法咖啡
# 591          591  26865471.0              南投縣埔里鎮同聲里南興街１６７號   ＹＯＵＮＧ冰館
# 612          612  39688718.0       南投縣埔里鎮大城里０３０鄰安四街１６３巷３２號    大碗公埔里店
# 694          694  24895534.0             南投縣埔里鎮水頭里水頭路５６―１號  歐根國際有限公司
# 744          744  47590127.0            南投縣埔里鎮西門里中正路４６６號１樓  綠翡淬鮮果手作茶
# 906          906  88454596.0             南投縣竹山鎮延和里江西路３之５８號      高源茶飲
# 1007        1007  85063997.0               南投縣竹山鎮竹山里祖師街３２號    橙城有限公司
# 1133        1133  87016205.0  南投縣草屯鎮和平里育英街１２９號右邊（草屯段８９４地號）     這裡飲料吧
# 1182        1182  72426188.0        南投縣草屯鎮富寮里０１９鄰宅內街１６６巷８號    啾茶棧水果冰
# 1241        1241  72494967.0              南投縣草屯鎮復興里復興路４６９號      安婕商行
# 1248        1248  87833629.0            南投縣草屯鎮敦和里仁愛街２１，２３號     龍仙茶藝館
# 1303        1303  38909896.0             南投縣草屯鎮新豐里中正路１０３９號     宸瑄企業社
# 1374        1374  47593243.0        南投縣草屯鎮玉峰里００７鄰中正路７５８號１樓      正展商行
# 1501        1501  19260526.0             南投縣魚池鄉水社村中山路９５號１樓    廣成興餐飲館
#
#             資本額       設立日期       停業日期 使用統一發票      行業代號          名稱
# 79      30000.0  1000809.0  1101101.0      N  563111.0  冰果店、冷（熱）飲店
# 201      5000.0  1060712.0  1101101.0      N  563111.0  冰果店、冷（熱）飲店
# 213    200000.0  1071222.0  1110310.0      N  563111.0  冰果店、冷（熱）飲店
# 319     10000.0  1100913.0  1101117.0      N  563111.0  冰果店、冷（熱）飲店
# 329      3000.0   870622.0  1101228.0      N  563111.0  冰果店、冷（熱）飲店
# 353    200000.0  1100303.0  1101114.0      N  563112.0         咖啡館
# 490     10000.0  1050301.0  1100916.0      N  563112.0         咖啡館
# 591     16000.0  1000510.0  1101119.0      N  563111.0  冰果店、冷（熱）飲店
# 612      3000.0  1010501.0  1110225.0      N  563111.0  冰果店、冷（熱）飲店
# 694    450000.0  1040507.0  1110228.0      Y  563111.0  冰果店、冷（熱）飲店
# 744     50000.0  1051223.0  1101126.0      N  563111.0  冰果店、冷（熱）飲店
# 906    200000.0  1100913.0  1101213.0      Y  563111.0  冰果店、冷（熱）飲店
# 1007  8100000.0  1081003.0  1110401.0      Y  563111.0  冰果店、冷（熱）飲店
# 1133    60000.0  1081203.0  1110101.0      N  563111.0  冰果店、冷（熱）飲店
# 1182     5000.0  1060707.0  1100913.0      N  563111.0  冰果店、冷（熱）飲店
# 1241     8000.0  1061201.0  1101219.0      N  563112.0         咖啡館
# 1248     3000.0   851004.0  1100630.0      N  563113.0         茶藝館
# 1303    50000.0  1030508.0  1101126.0      N  563200.0      調理飲料攤販
# 1374     5000.0  1060512.0  1100810.0      N  563111.0  冰果店、冷（熱）飲店
# 1501   200000.0   901224.0  1101001.0      N  563111.0  冰果店、冷（熱）飲店

# %%
# 存檔
drinkch.to_csv('../data/change_drinks.csv',encoding='utf_8_sig',index=False)
